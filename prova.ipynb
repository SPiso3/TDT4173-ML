# %%
import pandas as pd 
import xgboost as xgb
import numpy as np
pd.set_option('display.max_rows', None)

# %%
train = pd.read_csv('ais_train.csv', sep='|')
train[train['vesselId'] == '61e9f3a8b937134a3c4bfdf7']
# Out:
#                         time    cog   sog  rot  heading  navstat       etaRaw  \
# 0        2024-01-01 00:00:25  284.0   0.7    0       88        0  01-09 23:00
# 2672     2024-01-01 06:09:08   92.8  14.2    0       90        0  01-09 23:00
# 2947     2024-01-01 06:38:19   90.5  14.3    0       88        0  01-09 23:00
# 3093     2024-01-01 06:58:55   88.2  14.3    0       86        0  01-09 23:00
# 3140     2024-01-01 07:15:56   88.3  12.3    0       86        0  01-09 23:00
# 3280     2024-01-01 07:28:15   86.8  11.7    0       85        0  01-09 23:00
# 3586     2024-01-01 08:03:35   70.4  15.2    0       67        0  01-09 23:00
# 4816     2024-01-01 10:49:39   91.1  15.0    0       91        0  01-09 23:00
# 5056     2024-01-01 11:18:34   96.7  15.1    0       95        0  01-09 23:00
# 5198     2024-01-01 11:38:47   98.1  14.7  127       98        0  01-09 23:00
# 5389     2024-01-01 11:59:52  131.1  14.5    0      131        0  01-09 23:00
# ...

# %%
df[df['vesselId'] == '61e9f3a8b937134a3c4bfdf7'].count()
# Out:
# time         1550
# cog          1550
# sog          1550
# rot          1550
# heading      1550
# navstat      1550
# etaRaw       1550
# latitude     1550
# longitude    1550
# vesselId     1550
# portId       1550
# dtype: int64

# %% [markdown]
# ## Trying to merge port and vessels on homePort (FAILED)

# %%
schedules = pd.read_csv('ports.csv', sep='|')
